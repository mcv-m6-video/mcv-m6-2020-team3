# %%
# !git clone https://github.com/matterport/Mask_RCNN
# Out:
# fatal: destination path 'Mask_RCNN' already exists and is not an empty directory.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pwd
import os
os.chdir("/content/drive/My Drive/Colab Notebooks/M6/week3")
# !ls
# !pwd
# Out:
# /content
# “aidl2019_cv_lab2_segmentation.ipynb”的副本  Mask_RCNN		utils_w3.py
# Datasets				     __pycache__	work.ipynb
# Datasets.zip				     utils_Gaussian.py
# /content/drive/My Drive/Colab Notebooks/M6/week3

# %%
import os
import numpy as np
import sys
import random
import tensorflow as tf
import matplotlib.pyplot as plt
import skimage
import cv2
import utils_w3 as utw3
from utils_Gaussian import read_video_and_divide, calculate_mean_std_first_part_video, calculate_mask, find_detections
from tqdm import tqdm
# Root directory of the project
ROOT_DIR = os.path.abspath("./Mask_RCNN")

# Import Mask RCNN
sys.path.append(ROOT_DIR)  # To find local version of the library
from mrcnn import utils
from mrcnn import visualize
from mrcnn.config import Config
from mrcnn.visualize import display_images
import mrcnn.model as modellib
from mrcnn.model import log


#%matplotlib inline

# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "logs")

# Local path to trained weights file
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")
# Download COCO trained weights from Releases if needed
if not os.path.exists(COCO_MODEL_PATH):
    utils.download_trained_weights(COCO_MODEL_PATH)

# # Path to Shapes trained weights
SHAPES_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_shapes.h5")
sys.path.append(os.path.join(ROOT_DIR, "samples/coco/"))
print (ROOT_DIR)
import coco
config = coco.CocoConfig()
# Override the training configurations with a few
# changes for inferencing.
class InferenceConfig(config.__class__):
    # Run detection on one image at a time
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

config = InferenceConfig()
config.display()
DEVICE = "/gpu:0"  # /cpu:0 or /gpu:0
TEST_MODE = "inference"


def get_ax(rows=1, cols=1, size=16):
    """Return a Matplotlib Axes array to be used in
    all visualizations in the notebook. Provide a
    central point to control graph sizes.

    Adjust the size attribute to control how big to render images
    """
    _, ax = plt.subplots(rows, cols, figsize=(size * cols, size * rows))
    return ax
# COCO Class names
# Index of the class in the list is its ID. For example, to get ID of
# the teddy bear class, use: class_names.index('teddy bear')
class_names = ['BG', 'person', 'bicycle', 'car', 'motorcycle', 'airplane',
               'bus', 'train', 'truck', 'boat', 'traffic light',
               'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird',
               'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear',
               'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie',
               'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball',
               'kite', 'baseball bat', 'baseball glove', 'skateboard',
               'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup',
               'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple',
               'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza',
               'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed',
               'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote',
               'keyboard', 'cell phone', 'microwave', 'oven', 'toaster',
               'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors',
               'teddy bear', 'hair drier', 'toothbrush']

with tf.device(DEVICE):
    model = modellib.MaskRCNN(mode="inference", model_dir=MODEL_DIR, config = config)

# Set weights file path
if config.NAME == "shapes":
    weights_path = SHAPES_MODEL_PATH
elif config.NAME == "coco":
    weights_path = COCO_MODEL_PATH
# Or, uncomment to load the last model you trained
# weights_path = model.find_last()

# Load weights
print("Loading weights ", weights_path)
model.load_weights(weights_path, by_name=True)
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# /content/drive/My Drive/Colab Notebooks/M6/week3/Mask_RCNN
#
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                93
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           coco
# NUM_CLASSES                    81
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                1000
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001
#
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2139: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2239: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Colab Notebooks/M6/week3/Mask_RCNN/mrcnn/model.py:341: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Colab Notebooks/M6/week3/Mask_RCNN/mrcnn/model.py:399: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/drive/My Drive/Colab Notebooks/M6/week3/Mask_RCNN/mrcnn/model.py:423: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead
# WARNING:tensorflow:From /content/drive/My Drive/Colab Notebooks/M6/week3/Mask_RCNN/mrcnn/model.py:720: The name tf.sets.set_intersection is deprecated. Please use tf.sets.intersection instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Colab Notebooks/M6/week3/Mask_RCNN/mrcnn/model.py:722: The name tf.sparse_tensor_to_dense is deprecated. Please use tf.sparse.to_dense instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Colab Notebooks/M6/week3/Mask_RCNN/mrcnn/model.py:772: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# Loading weights  /content/drive/My Drive/Colab Notebooks/M6/week3/Mask_RCNN/mask_rcnn_coco.h5
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.

# %%
'''
Test the network with different images taken from our dataset. Take into account that the network can only predict classes from COCO.
'''
video_length = 2141
# video_length = 2141
# video_length = 100
video_split_ratio = 0.25
# video_path = "./Datasets/AICity_data/train/S03/c010/vdo.avi"
video_path = "./Datasets/AICity/frames/"
groundtruth_xml_path = 'Datasets/AICity/aicity_annotations.xml'
# groundtruth_path = "../datasets/AICity_data/train/S03/c010/gt/gt.txt"
roi_path = 'Datasets/AICity_data/train/S03/c010/roi.jpg'
# roi = cv2.cvtColor(cv2.imread(roi_path))
ver = True
# print("Reading annotations...")
# groundTruth = utw3.read_annotations(groundtruth_xml_path, video_length)
# gt_filtered = [x for x in groundTruth if x['frame'] > int(video_length * video_split_ratio)]
# video_first_part, video_second_part, divide_frame = \
#     read_video_and_divide(video_path, video_length=video_length, video_split_ratio=video_split_ratio)

# %%
detections = []
frame_id = 0
for i in tqdm(range(video_length)):
    frame_id = frame_id + 1

    filename = "{}{}.jpg".format(video_path, str(i + 1).zfill(5))

    image = cv2.imread(filename)

    # Run detection
    results = model.detect([image], verbose=0)
    r = results[0]
    class_id = r['class_ids']
    # print (class_id)
    boxes = r['rois']
    confidence = r['scores']
    for j in range(class_id.shape[0]):
        if class_id[j] == 3:
            bbox = boxes[j, :]
            detection = {}
            box_h = bbox[2] - bbox[0]
            box_w = bbox[3] - bbox[1]
            detection['frame'] = frame_id
            detection['left'] = bbox[1]
            detection['top'] = bbox[0]
            detection['width'] = box_w
            detection['height'] = box_h
            detection['confidence'] = confidence[j]
            detections.append(detection)
# Out:
# 100%|██████████| 2141/2141 [39:01<00:00,  1.15s/it]

# %%
for detection in detections:
  print (detection)
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# {'frame': 1414, 'left': 561, 'top': 89, 'width': 101, 'height': 79, 'confidence': 0.9077573}
# {'frame': 1414, 'left': 896, 'top': 82, 'width': 116, 'height': 62, 'confidence': 0.8576292}
# {'frame': 1414, 'left': 441, 'top': 135, 'width': 31, 'height': 39, 'confidence': 0.75358075}
# {'frame': 1415, 'left': 1297, 'top': 360, 'width': 225, 'height': 177, 'confidence': 0.9947337}
# {'frame': 1415, 'left': 1176, 'top': 103, 'width': 52, 'height': 57, 'confidence': 0.9812665}
# {'frame': 1415, 'left': 561, 'top': 93, 'width': 99, 'height': 74, 'confidence': 0.93000954}
# {'frame': 1415, 'left': 897, 'top': 81, 'width': 116, 'height': 65, 'confidence': 0.8617858}
# {'frame': 1415, 'left': 442, 'top': 139, 'width': 30, 'height': 34, 'confidence': 0.7034069}
# {'frame': 1416, 'left': 1297, 'top': 360, 'width': 225, 'height': 177, 'confidence': 0.99463356}
# {'frame': 1416, 'left': 1176, 'top': 103, 'width': 53, 'height': 57, 'confidence': 0.9817121}
# {'frame': 1416, 'left': 561, 'top': 94, 'width': 100, 'height': 73, 'confidence': 0.9439639}
# {'frame': 1416, 'left': 926, 'top': 925, 'width': 448, 'height': 151, 'confidence': 0.91958773}
# {'frame': 1416, 'left': 902, 'top': 80, 'width': 110, 'height': 63, 'confidence': 0.82977635}
# {'frame': 1417, 'left': 1295, 'top': 363, 'width': 227, 'height': 172, 'confidence': 0.99264866}
# {'frame': 1417, 'left': 1177, 'top': 104, 'width': 52, 'height': 54, 'confidence': 0.9687982}
# {'frame': 1417, 'left': 562, 'top': 92, 'width': 99, 'height': 75, 'confidence': 0.9449625}
# {'frame': 1417, 'left': 890, 'top': 79, 'width': 124, 'height': 65, 'confidence': 0.9262864}
# {'frame': 1417, 'left': 544, 'top': 113, 'width': 26, 'height': 42, 'confidence': 0.76733905}
# {'frame': 1418, 'left': 1294, 'top': 362, 'width': 228, 'height': 174, 'confidence': 0.9899053}
# {'frame': 1418, 'left': 1177, 'top': 103, 'width': 53, 'height': 56, 'confidence': 0.97009575}
# {'frame': 1418, 'left': 893, 'top': 80, 'width': 119, 'height': 63, 'confidence': 0.9294423}
# {'frame': 1418, 'left': 561, 'top': 92, 'width': 101, 'height': 74, 'confidence': 0.9233883}
# {'frame': 1418, 'left': 440, 'top': 134, 'width': 33, 'height': 39, 'confidence': 0.7449663}
# {'frame': 1418, 'left': 959, 'top': 851, 'width': 416, 'height': 227, 'confidence': 0.7044039}
# {'frame': 1419, 'left': 1293, 'top': 361, 'width': 228, 'height': 175, 'confidence': 0.9915012}
# {'frame': 1419, 'left': 961, 'top': 829, 'width': 383, 'height': 249, 'confidence': 0.97241807}
# {'frame': 1419, 'left': 1177, 'top': 104, 'width': 53, 'height': 56, 'confidence': 0.97028315}
# {'frame': 1419, 'left': 883, 'top': 80, 'width': 131, 'height': 65, 'confidence': 0.92636013}
# {'frame': 1419, 'left': 563, 'top': 93, 'width': 99, 'height': 72, 'confidence': 0.90281457}
# {'frame': 1419, 'left': 545, 'top': 113, 'width': 26, 'height': 42, 'confidence': 0.7975129}
# {'frame': 1419, 'left': 441, 'top': 135, 'width': 33, 'height': 38, 'confidence': 0.75387657}
# {'frame': 1420, 'left': 1292, 'top': 358, 'width': 229, 'height': 177, 'confidence': 0.9908318}
# {'frame': 1420, 'left': 1177, 'top': 103, 'width': 52, 'height': 56, 'confidence': 0.96913046}
# {'frame': 1420, 'left': 980, 'top': 793, 'width': 386, 'height': 287, 'confidence': 0.9552153}
# {'frame': 1420, 'left': 563, 'top': 94, 'width': 98, 'height': 71, 'confidence': 0.93476236}
# {'frame': 1420, 'left': 887, 'top': 80, 'width': 128, 'height': 65, 'confidence': 0.90932876}
# {'frame': 1420, 'left': 441, 'top': 135, 'width': 33, 'height': 37, 'confidence': 0.7576306}
# {'frame': 1421, 'left': 1292, 'top': 358, 'width': 230, 'height': 177, 'confidence': 0.98921484}
# {'frame': 1421, 'left': 995, 'top': 766, 'width': 366, 'height': 302, 'confidence': 0.98893654}
# {'frame': 1421, 'left': 1177, 'top': 104, 'width': 52, 'height': 55, 'confidence': 0.9676875}
# {'frame': 1421, 'left': 564, 'top': 92, 'width': 95, 'height': 74, 'confidence': 0.9457759}
# {'frame': 1421, 'left': 441, 'top': 135, 'width': 32, 'height': 38, 'confidence': 0.76650023}
# {'frame': 1421, 'left': 889, 'top': 79, 'width': 124, 'height': 65, 'confidence': 0.73551756}
# {'frame': 1422, 'left': 1293, 'top': 358, 'width': 229, 'height': 177, 'confidence': 0.98907566}
# {'frame': 1422, 'left': 1005, 'top': 733, 'width': 351, 'height': 316, 'confidence': 0.97352785}
# {'frame': 1422, 'left': 1177, 'top': 102, 'width': 51, 'height': 56, 'confidence': 0.9639017}
# {'frame': 1422, 'left': 562, 'top': 93, 'width': 97, 'height': 73, 'confidence': 0.94210106}
# {'frame': 1422, 'left': 889, 'top': 78, 'width': 126, 'height': 67, 'confidence': 0.7982025}
# {'frame': 1422, 'left': 441, 'top': 136, 'width': 33, 'height': 36, 'confidence': 0.7119375}
# {'frame': 1423, 'left': 1293, 'top': 358, 'width': 229, 'height': 178, 'confidence': 0.9902772}
# {'frame': 1423, 'left': 999, 'top': 708, 'width': 364, 'height': 302, 'confidence': 0.97068775}
# {'frame': 1423, 'left': 1176, 'top': 104, 'width': 52, 'height': 54, 'confidence': 0.9644712}
# {'frame': 1423, 'left': 562, 'top': 94, 'width': 97, 'height': 72, 'confidence': 0.9443977}
# {'frame': 1423, 'left': 887, 'top': 78, 'width': 129, 'height': 67, 'confidence': 0.7945917}
# {'frame': 1423, 'left': 441, 'top': 136, 'width': 33, 'height': 36, 'confidence': 0.7206845}
# {'frame': 1424, 'left': 1293, 'top': 358, 'width': 229, 'height': 177, 'confidence': 0.9917807}
# {'frame': 1424, 'left': 1012, 'top': 683, 'width': 340, 'height': 293, 'confidence': 0.96556973}
# {'frame': 1424, 'left': 1177, 'top': 103, 'width': 51, 'height': 55, 'confidence': 0.96015924}
# {'frame': 1424, 'left': 562, 'top': 94, 'width': 97, 'height': 72, 'confidence': 0.94297993}
# {'frame': 1424, 'left': 893, 'top': 80, 'width': 122, 'height': 65, 'confidence': 0.80262315}
# {'frame': 1424, 'left': 441, 'top': 135, 'width': 33, 'height': 37, 'confidence': 0.7992896}
# {'frame': 1425, 'left': 1292, 'top': 358, 'width': 230, 'height': 177, 'confidence': 0.9902243}
# {'frame': 1425, 'left': 1009, 'top': 656, 'width': 336, 'height': 291, 'confidence': 0.9799233}
# {'frame': 1425, 'left': 1177, 'top': 102, 'width': 51, 'height': 56, 'confidence': 0.96139514}
# {'frame': 1425, 'left': 562, 'top': 95, 'width': 98, 'height': 70, 'confidence': 0.94686043}
# {'frame': 1425, 'left': 891, 'top': 79, 'width': 123, 'height': 65, 'confidence': 0.7999193}
# {'frame': 1425, 'left': 441, 'top': 136, 'width': 33, 'height': 36, 'confidence': 0.7681076}
# {'frame': 1426, 'left': 1292, 'top': 359, 'width': 230, 'height': 176, 'confidence': 0.99094594}
# {'frame': 1426, 'left': 1177, 'top': 104, 'width': 51, 'height': 55, 'confidence': 0.9665317}
# {'frame': 1426, 'left': 1014, 'top': 637, 'width': 328, 'height': 276, 'confidence': 0.92223865}
# {'frame': 1426, 'left': 561, 'top': 94, 'width': 97, 'height': 73, 'confidence': 0.92198384}
# {'frame': 1426, 'left': 888, 'top': 80, 'width': 124, 'height': 63, 'confidence': 0.81585497}
# {'frame': 1426, 'left': 441, 'top': 136, 'width': 33, 'height': 36, 'confidence': 0.77046514}
# {'frame': 1427, 'left': 1293, 'top': 359, 'width': 228, 'height': 177, 'confidence': 0.9918697}
# {'frame': 1427, 'left': 1177, 'top': 103, 'width': 53, 'height': 56, 'confidence': 0.9749187}
# {'frame': 1427, 'left': 1017, 'top': 608, 'width': 320, 'height': 279, 'confidence': 0.9481278}
# {'frame': 1427, 'left': 563, 'top': 94, 'width': 96, 'height': 72, 'confidence': 0.9426842}
# {'frame': 1427, 'left': 895, 'top': 79, 'width': 120, 'height': 65, 'confidence': 0.8256942}
# {'frame': 1427, 'left': 442, 'top': 139, 'width': 31, 'height': 33, 'confidence': 0.789349}
# {'frame': 1428, 'left': 1292, 'top': 359, 'width': 229, 'height': 177, 'confidence': 0.98938024}
# {'frame': 1428, 'left': 1177, 'top': 103, 'width': 53, 'height': 57, 'confidence': 0.9799161}
# {'frame': 1428, 'left': 1017, 'top': 592, 'width': 315, 'height': 271, 'confidence': 0.9700394}
# {'frame': 1428, 'left': 563, 'top': 93, 'width': 97, 'height': 72, 'confidence': 0.95054877}
# {'frame': 1428, 'left': 893, 'top': 81, 'width': 121, 'height': 63, 'confidence': 0.8222344}
# {'frame': 1428, 'left': 441, 'top': 139, 'width': 32, 'height': 33, 'confidence': 0.81276315}
# {'frame': 1428, 'left': 545, 'top': 113, 'width': 25, 'height': 37, 'confidence': 0.8015173}
# {'frame': 1429, 'left': 1294, 'top': 360, 'width': 227, 'height': 175, 'confidence': 0.9920161}
# {'frame': 1429, 'left': 1176, 'top': 103, 'width': 54, 'height': 57, 'confidence': 0.9761362}
# {'frame': 1429, 'left': 1016, 'top': 575, 'width': 313, 'height': 258, 'confidence': 0.97218215}
# {'frame': 1429, 'left': 564, 'top': 93, 'width': 95, 'height': 72, 'confidence': 0.9487564}
# {'frame': 1429, 'left': 892, 'top': 79, 'width': 123, 'height': 66, 'confidence': 0.8880662}
# {'frame': 1429, 'left': 441, 'top': 137, 'width': 33, 'height': 35, 'confidence': 0.83466405}
# {'frame': 1429, 'left': 545, 'top': 114, 'width': 24, 'height': 34, 'confidence': 0.8271118}
# {'frame': 1430, 'left': 1296, 'top': 359, 'width': 226, 'height': 176, 'confidence': 0.99402726}
# {'frame': 1430, 'left': 1176, 'top': 102, 'width': 53, 'height': 58, 'confidence': 0.97774386}
# {'frame': 1430, 'left': 1015, 'top': 550, 'width': 307, 'height': 257, 'confidence': 0.9756269}
# {'frame': 1430, 'left': 886, 'top': 81, 'width': 130, 'height': 64, 'confidence': 0.9522967}
# {'frame': 1430, 'left': 562, 'top': 93, 'width': 99, 'height': 72, 'confidence': 0.9479557}
# {'frame': 1430, 'left': 441, 'top': 136, 'width': 32, 'height': 36, 'confidence': 0.8364694}
# {'frame': 1430, 'left': 544, 'top': 115, 'width': 26, 'height': 34, 'confidence': 0.8124525}
# {'frame': 1431, 'left': 1296, 'top': 360, 'width': 225, 'height': 175, 'confidence': 0.9919521}
# {'frame': 1431, 'left': 1176, 'top': 102, 'width': 53, 'height': 58, 'confidence': 0.9768695}
# {'frame': 1431, 'left': 1013, 'top': 536, 'width': 301, 'height': 251, 'confidence': 0.9543736}
# {'frame': 1431, 'left': 561, 'top': 92, 'width': 100, 'height': 74, 'confidence': 0.94384676}
# {'frame': 1431, 'left': 899, 'top': 78, 'width': 117, 'height': 66, 'confidence': 0.90897965}
# {'frame': 1431, 'left': 441, 'top': 135, 'width': 32, 'height': 37, 'confidence': 0.8407097}
# {'frame': 1431, 'left': 880, 'top': 89, 'width': 52, 'height': 50, 'confidence': 0.70084554}
# {'frame': 1432, 'left': 1296, 'top': 360, 'width': 225, 'height': 175, 'confidence': 0.9925055}
# {'frame': 1432, 'left': 1176, 'top': 102, 'width': 53, 'height': 57, 'confidence': 0.9760677}
# {'frame': 1432, 'left': 1017, 'top': 523, 'width': 290, 'height': 242, 'confidence': 0.96769565}
# {'frame': 1432, 'left': 561, 'top': 91, 'width': 101, 'height': 75, 'confidence': 0.95164984}
# {'frame': 1432, 'left': 894, 'top': 79, 'width': 122, 'height': 66, 'confidence': 0.8991037}
# {'frame': 1432, 'left': 441, 'top': 135, 'width': 32, 'height': 37, 'confidence': 0.78345925}
# {'frame': 1433, 'left': 1296, 'top': 360, 'width': 225, 'height': 175, 'confidence': 0.99212193}
# {'frame': 1433, 'left': 1176, 'top': 102, 'width': 53, 'height': 56, 'confidence': 0.9755422}
# {'frame': 1433, 'left': 562, 'top': 88, 'width': 100, 'height': 79, 'confidence': 0.93661034}
# {'frame': 1433, 'left': 898, 'top': 78, 'width': 119, 'height': 66, 'confidence': 0.9221024}
# {'frame': 1433, 'left': 1010, 'top': 502, 'width': 294, 'height': 241, 'confidence': 0.88980424}
# {'frame': 1433, 'left': 441, 'top': 135, 'width': 32, 'height': 37, 'confidence': 0.77527654}
# {'frame': 1433, 'left': 541, 'top': 114, 'width': 31, 'height': 39, 'confidence': 0.7173035}
# {'frame': 1434, 'left': 1296, 'top': 360, 'width': 225, 'height': 175, 'confidence': 0.9917754}
# {'frame': 1434, 'left': 1176, 'top': 102, 'width': 53, 'height': 55, 'confidence': 0.97276014}
# {'frame': 1434, 'left': 1013, 'top': 485, 'width': 286, 'height': 237, 'confidence': 0.95609266}
# {'frame': 1434, 'left': 897, 'top': 79, 'width': 117, 'height': 65, 'confidence': 0.93572783}
# {'frame': 1434, 'left': 562, 'top': 89, 'width': 100, 'height': 78, 'confidence': 0.92636585}
# {'frame': 1434, 'left': 441, 'top': 135, 'width': 32, 'height': 37, 'confidence': 0.8073471}
# {'frame': 1434, 'left': 542, 'top': 115, 'width': 28, 'height': 41, 'confidence': 0.7154337}
# {'frame': 1435, 'left': 1295, 'top': 361, 'width': 226, 'height': 175, 'confidence': 0.9874605}
# {'frame': 1435, 'left': 1012, 'top': 472, 'width': 274, 'height': 234, 'confidence': 0.9842831}
# {'frame': 1435, 'left': 1176, 'top': 102, 'width': 54, 'height': 55, 'confidence': 0.970524}
# {'frame': 1435, 'left': 900, 'top': 79, 'width': 115, 'height': 65, 'confidence': 0.93795604}
# {'frame': 1435, 'left': 563, 'top': 91, 'width': 100, 'height': 76, 'confidence': 0.92993283}
# {'frame': 1435, 'left': 441, 'top': 136, 'width': 32, 'height': 36, 'confidence': 0.8167662}
# {'frame': 1436, 'left': 1176, 'top': 103, 'width': 53, 'height': 56, 'confidence': 0.9783664}
# {'frame': 1436, 'left': 1290, 'top': 359, 'width': 231, 'height': 180, 'confidence': 0.9738299}
# {'frame': 1436, 'left': 562, 'top': 91, 'width': 101, 'height': 75, 'confidence': 0.94784826}
# {'frame': 1436, 'left': 1008, 'top': 459, 'width': 273, 'height': 225, 'confidence': 0.94048256}
# {'frame': 1436, 'left': 892, 'top': 81, 'width': 124, 'height': 63, 'confidence': 0.9002254}
# {'frame': 1436, 'left': 440, 'top': 136, 'width': 33, 'height': 37, 'confidence': 0.8254619}
# {'frame': 1437, 'left': 1286, 'top': 360, 'width': 235, 'height': 177, 'confidence': 0.98169005}
# {'frame': 1437, 'left': 1009, 'top': 444, 'width': 264, 'height': 223, 'confidence': 0.96499765}
# {'frame': 1437, 'left': 1176, 'top': 104, 'width': 54, 'height': 53, 'confidence': 0.9538412}
# {'frame': 1437, 'left': 895, 'top': 81, 'width': 118, 'height': 64, 'confidence': 0.92535555}
# {'frame': 1437, 'left': 564, 'top': 88, 'width': 97, 'height': 78, 'confidence': 0.9164963}
# {'frame': 1437, 'left': 442, 'top': 136, 'width': 32, 'height': 36, 'confidence': 0.7763472}
# {'frame': 1438, 'left': 1291, 'top': 362, 'width': 229, 'height': 173, 'confidence': 0.99123657}
# {'frame': 1438, 'left': 1176, 'top': 103, 'width': 53, 'height': 55, 'confidence': 0.96460986}
# {'frame': 1438, 'left': 997, 'top': 430, 'width': 271, 'height': 223, 'confidence': 0.9603432}
# {'frame': 1438, 'left': 563, 'top': 91, 'width': 100, 'height': 75, 'confidence': 0.9258048}
# {'frame': 1438, 'left': 900, 'top': 79, 'width': 113, 'height': 65, 'confidence': 0.90508056}
# {'frame': 1438, 'left': 442, 'top': 135, 'width': 31, 'height': 36, 'confidence': 0.7475101}
# {'frame': 1439, 'left': 1293, 'top': 361, 'width': 227, 'height': 174, 'confidence': 0.9915445}
# {'frame': 1439, 'left': 1000, 'top': 423, 'width': 249, 'height': 210, 'confidence': 0.9892546}
# {'frame': 1439, 'left': 1176, 'top': 102, 'width': 54, 'height': 57, 'confidence': 0.96005785}
# {'frame': 1439, 'left': 906, 'top': 78, 'width': 107, 'height': 66, 'confidence': 0.953071}
# {'frame': 1439, 'left': 562, 'top': 91, 'width': 101, 'height': 75, 'confidence': 0.9392172}
# {'frame': 1439, 'left': 442, 'top': 136, 'width': 31, 'height': 36, 'confidence': 0.7991841}
# {'frame': 1440, 'left': 1294, 'top': 361, 'width': 226, 'height': 174, 'confidence': 0.9909382}
# {'frame': 1440, 'left': 1177, 'top': 104, 'width': 51, 'height': 54, 'confidence': 0.95914835}
# {'frame': 1440, 'left': 993, 'top': 412, 'width': 254, 'height': 205, 'confidence': 0.9501013}
# {'frame': 1440, 'left': 899, 'top': 80, 'width': 113, 'height': 64, 'confidence': 0.9497358}
# {'frame': 1440, 'left': 562, 'top': 91, 'width': 100, 'height': 75, 'confidence': 0.92932904}
# {'frame': 1440, 'left': 442, 'top': 136, 'width': 31, 'height': 36, 'confidence': 0.72555}
# {'frame': 1441, 'left': 1291, 'top': 359, 'width': 231, 'height': 179, 'confidence': 0.9918242}
# {'frame': 1441, 'left': 989, 'top': 402, 'width': 252, 'height': 199, 'confidence': 0.97892386}
# {'frame': 1441, 'left': 1176, 'top': 103, 'width': 52, 'height': 54, 'confidence': 0.94825566}
# {'frame': 1441, 'left': 896, 'top': 80, 'width': 117, 'height': 64, 'confidence': 0.93359536}
# {'frame': 1441, 'left': 563, 'top': 90, 'width': 98, 'height': 76, 'confidence': 0.9238995}
# {'frame': 1442, 'left': 1294, 'top': 360, 'width': 227, 'height': 176, 'confidence': 0.9921624}
# {'frame': 1442, 'left': 1176, 'top': 104, 'width': 52, 'height': 54, 'confidence': 0.9629449}
# {'frame': 1442, 'left': 893, 'top': 79, 'width': 122, 'height': 66, 'confidence': 0.9450416}
# {'frame': 1442, 'left': 563, 'top': 91, 'width': 100, 'height': 75, 'confidence': 0.9399224}
# {'frame': 1442, 'left': 991, 'top': 390, 'width': 240, 'height': 198, 'confidence': 0.88266164}
# {'frame': 1443, 'left': 986, 'top': 381, 'width': 238, 'height': 191, 'confidence': 0.9904338}
# {'frame': 1443, 'left': 1293, 'top': 359, 'width': 228, 'height': 178, 'confidence': 0.9882876}
# {'frame': 1443, 'left': 1176, 'top': 104, 'width': 53, 'height': 53, 'confidence': 0.95925313}
# {'frame': 1443, 'left': 563, 'top': 87, 'width': 100, 'height': 79, 'confidence': 0.9376625}
# {'frame': 1443, 'left': 892, 'top': 79, 'width': 124, 'height': 66, 'confidence': 0.93456304}
# {'frame': 1444, 'left': 1293, 'top': 359, 'width': 228, 'height': 178, 'confidence': 0.99249035}
# {'frame': 1444, 'left': 982, 'top': 370, 'width': 235, 'height': 188, 'confidence': 0.96868736}
# {'frame': 1444, 'left': 1176, 'top': 104, 'width': 52, 'height': 52, 'confidence': 0.9665545}
# {'frame': 1444, 'left': 563, 'top': 89, 'width': 99, 'height': 77, 'confidence': 0.9419912}
# {'frame': 1444, 'left': 900, 'top': 79, 'width': 114, 'height': 65, 'confidence': 0.93722826}
# {'frame': 1445, 'left': 1294, 'top': 359, 'width': 226, 'height': 177, 'confidence': 0.9911965}
# {'frame': 1445, 'left': 1176, 'top': 104, 'width': 52, 'height': 52, 'confidence': 0.96528274}
# {'frame': 1445, 'left': 563, 'top': 91, 'width': 99, 'height': 75, 'confidence': 0.9434711}
# {'frame': 1445, 'left': 900, 'top': 79, 'width': 112, 'height': 65, 'confidence': 0.93344325}
# {'frame': 1445, 'left': 974, 'top': 357, 'width': 235, 'height': 190, 'confidence': 0.87068576}
# {'frame': 1446, 'left': 1293, 'top': 359, 'width': 227, 'height': 177, 'confidence': 0.9889943}
# {'frame': 1446, 'left': 1176, 'top': 103, 'width': 52, 'height': 53, 'confidence': 0.96750945}
# {'frame': 1446, 'left': 563, 'top': 91, 'width': 98, 'height': 75, 'confidence': 0.9408909}
# {'frame': 1446, 'left': 899, 'top': 78, 'width': 113, 'height': 66, 'confidence': 0.9386769}
# {'frame': 1446, 'left': 976, 'top': 349, 'width': 233, 'height': 183, 'confidence': 0.7668107}
# {'frame': 1446, 'left': 442, 'top': 134, 'width': 32, 'height': 37, 'confidence': 0.7143416}
# {'frame': 1446, 'left': 647, 'top': 95, 'width': 33, 'height': 45, 'confidence': 0.7091455}
# {'frame': 1447, 'left': 1294, 'top': 359, 'width': 226, 'height': 178, 'confidence': 0.99067664}
# {'frame': 1447, 'left': 1175, 'top': 103, 'width': 54, 'height': 54, 'confidence': 0.9718299}
# {'frame': 1447, 'left': 563, 'top': 94, 'width': 100, 'height': 71, 'confidence': 0.95013005}
# {'frame': 1447, 'left': 892, 'top': 80, 'width': 121, 'height': 64, 'confidence': 0.923722}
# {'frame': 1447, 'left': 972, 'top': 340, 'width': 226, 'height': 182, 'confidence': 0.7852632}
# {'frame': 1447, 'left': 441, 'top': 135, 'width': 32, 'height': 37, 'confidence': 0.72461617}
# {'frame': 1447, 'left': 640, 'top': 87, 'width': 37, 'height': 50, 'confidence': 0.7233415}
# {'frame': 1448, 'left': 1294, 'top': 359, 'width': 226, 'height': 177, 'confidence': 0.9935581}
# {'frame': 1448, 'left': 1175, 'top': 103, 'width': 54, 'height': 54, 'confidence': 0.97338426}
# {'frame': 1448, 'left': 564, 'top': 91, 'width': 97, 'height': 75, 'confidence': 0.93210983}
# {'frame': 1448, 'left': 974, 'top': 330, 'width': 217, 'height': 179, 'confidence': 0.9254427}
# {'frame': 1448, 'left': 886, 'top': 81, 'width': 129, 'height': 64, 'confidence': 0.92447126}
# {'frame': 1449, 'left': 1295, 'top': 359, 'width': 225, 'height': 178, 'confidence': 0.99319977}
# {'frame': 1449, 'left': 976, 'top': 324, 'width': 214, 'height': 175, 'confidence': 0.9767973}
# {'frame': 1449, 'left': 1175, 'top': 103, 'width': 54, 'height': 55, 'confidence': 0.9741513}
# {'frame': 1449, 'left': 891, 'top': 80, 'width': 125, 'height': 65, 'confidence': 0.95047647}
# {'frame': 1449, 'left': 563, 'top': 95, 'width': 99, 'height': 69, 'confidence': 0.93323874}
# {'frame': 1449, 'left': 652, 'top': 106, 'width': 31, 'height': 34, 'confidence': 0.7012353}
# {'frame': 1450, 'left': 1295, 'top': 360, 'width': 225, 'height': 176, 'confidence': 0.99376255}
# {'frame': 1450, 'left': 974, 'top': 317, 'width': 211, 'height': 173, 'confidence': 0.9794758}
# {'frame': 1450, 'left': 1175, 'top': 103, 'width': 54, 'height': 56, 'confidence': 0.9732293}
# {'frame': 1450, 'left': 563, 'top': 95, 'width': 100, 'height': 69, 'confidence': 0.9333781}
# {'frame': 1450, 'left': 890, 'top': 79, 'width': 126, 'height': 66, 'confidence': 0.90773726}
# {'frame': 1450, 'left': 643, 'top': 92, 'width': 40, 'height': 44, 'confidence': 0.71621597}
# {'frame': 1451, 'left': 1295, 'top': 360, 'width': 225, 'height': 177, 'confidence': 0.9940315}
# {'frame': 1451, 'left': 966, 'top': 309, 'width': 213, 'height': 169, 'confidence': 0.978122}
# {'frame': 1451, 'left': 1176, 'top': 103, 'width': 53, 'height': 55, 'confidence': 0.9763964}
# {'frame': 1451, 'left': 564, 'top': 95, 'width': 99, 'height': 70, 'confidence': 0.9494608}
# {'frame': 1451, 'left': 893, 'top': 78, 'width': 121, 'height': 67, 'confidence': 0.9089085}
# {'frame': 1451, 'left': 642, 'top': 92, 'width': 40, 'height': 44, 'confidence': 0.79302377}
# {'frame': 1451, 'left': 544, 'top': 116, 'width': 27, 'height': 37, 'confidence': 0.74602604}
# {'frame': 1452, 'left': 1295, 'top': 360, 'width': 225, 'height': 177, 'confidence': 0.9923269}
# {'frame': 1452, 'left': 1175, 'top': 102, 'width': 54, 'height': 56, 'confidence': 0.9765322}
# {'frame': 1452, 'left': 960, 'top': 306, 'width': 216, 'height': 164, 'confidence': 0.9691375}
# {'frame': 1452, 'left': 565, 'top': 95, 'width': 97, 'height': 71, 'confidence': 0.9635722}
# {'frame': 1452, 'left': 891, 'top': 79, 'width': 124, 'height': 66, 'confidence': 0.90451014}
# {'frame': 1452, 'left': 643, 'top': 93, 'width': 39, 'height': 41, 'confidence': 0.847783}
# {'frame': 1452, 'left': 544, 'top': 116, 'width': 27, 'height': 37, 'confidence': 0.7327547}
# {'frame': 1453, 'left': 1294, 'top': 361, 'width': 227, 'height': 175, 'confidence': 0.9932795}
# {'frame': 1453, 'left': 567, 'top': 96, 'width': 93, 'height': 69, 'confidence': 0.9778276}
# {'frame': 1453, 'left': 1176, 'top': 104, 'width': 52, 'height': 54, 'confidence': 0.96851337}
# {'frame': 1453, 'left': 957, 'top': 294, 'width': 212, 'height': 166, 'confidence': 0.9471885}
# {'frame': 1453, 'left': 650, 'top': 101, 'width': 33, 'height': 34, 'confidence': 0.85205054}
# {'frame': 1453, 'left': 891, 'top': 80, 'width': 124, 'height': 65, 'confidence': 0.8500836}
# {'frame': 1454, 'left': 1292, 'top': 359, 'width': 229, 'height': 177, 'confidence': 0.9936986}
# {'frame': 1454, 'left': 958, 'top': 288, 'width': 202, 'height': 161, 'confidence': 0.9873847}
# {'frame': 1454, 'left': 1176, 'top': 104, 'width': 52, 'height': 55, 'confidence': 0.97183704}
# {'frame': 1454, 'left': 565, 'top': 95, 'width': 96, 'height': 71, 'confidence': 0.9711968}
# {'frame': 1454, 'left': 893, 'top': 80, 'width': 119, 'height': 64, 'confidence': 0.855274}
# {'frame': 1454, 'left': 653, 'top': 107, 'width': 32, 'height': 30, 'confidence': 0.83690184}
# {'frame': 1455, 'left': 956, 'top': 282, 'width': 200, 'height': 160, 'confidence': 0.9935503}
# {'frame': 1455, 'left': 1293, 'top': 360, 'width': 228, 'height': 176, 'confidence': 0.9934608}
# {'frame': 1455, 'left': 1176, 'top': 104, 'width': 52, 'height': 55, 'confidence': 0.97327155}
# {'frame': 1455, 'left': 566, 'top': 93, 'width': 94, 'height': 74, 'confidence': 0.9686465}
# {'frame': 1455, 'left': 653, 'top': 108, 'width': 34, 'height': 30, 'confidence': 0.8877452}
# {'frame': 1455, 'left': 894, 'top': 80, 'width': 118, 'height': 64, 'confidence': 0.8507572}
# {'frame': 1456, 'left': 1293, 'top': 360, 'width': 228, 'height': 176, 'confidence': 0.9926434}
# {'frame': 1456, 'left': 953, 'top': 277, 'width': 199, 'height': 158, 'confidence': 0.98626584}
# {'frame': 1456, 'left': 566, 'top': 92, 'width': 94, 'height': 75, 'confidence': 0.97310716}
# {'frame': 1456, 'left': 1176, 'top': 105, 'width': 52, 'height': 54, 'confidence': 0.97186184}
# {'frame': 1456, 'left': 652, 'top': 104, 'width': 36, 'height': 33, 'confidence': 0.8868059}
# {'frame': 1456, 'left': 894, 'top': 80, 'width': 118, 'height': 64, 'confidence': 0.84866613}
# {'frame': 1456, 'left': 1, 'top': 204, 'width': 327, 'height': 132, 'confidence': 0.70040244}
# {'frame': 1457, 'left': 1296, 'top': 362, 'width': 225, 'height': 174, 'confidence': 0.99424666}
# {'frame': 1457, 'left': 952, 'top': 273, 'width': 197, 'height': 157, 'confidence': 0.9882918}
# {'frame': 1457, 'left': 565, 'top': 94, 'width': 96, 'height': 71, 'confidence': 0.9795997}
# {'frame': 1457, 'left': 1176, 'top': 104, 'width': 52, 'height': 54, 'confidence': 0.9663404}
# {'frame': 1457, 'left': 654, 'top': 106, 'width': 38, 'height': 33, 'confidence': 0.9261513}
# {'frame': 1457, 'left': 897, 'top': 80, 'width': 118, 'height': 65, 'confidence': 0.85172343}
# {'frame': 1458, 'left': 1296, 'top': 361, 'width': 225, 'height': 175, 'confidence': 0.99494714}
# {'frame': 1458, 'left': 951, 'top': 268, 'width': 191, 'height': 152, 'confidence': 0.99295455}
# {'frame': 1458, 'left': 564, 'top': 94, 'width': 97, 'height': 71, 'confidence': 0.97930306}
# {'frame': 1458, 'left': 1176, 'top': 104, 'width': 52, 'height': 54, 'confidence': 0.96840745}
# {'frame': 1458, 'left': 652, 'top': 103, 'width': 38, 'height': 35, 'confidence': 0.9210081}
# {'frame': 1458, 'left': 896, 'top': 80, 'width': 119, 'height': 65, 'confidence': 0.84638876}
# {'frame': 1459, 'left': 1296, 'top': 361, 'width': 225, 'height': 175, 'confidence': 0.9947162}
# {'frame': 1459, 'left': 950, 'top': 261, 'width': 188, 'height': 153, 'confidence': 0.9927113}
# {'frame': 1459, 'left': 564, 'top': 94, 'width': 97, 'height': 71, 'confidence': 0.9795817}
# {'frame': 1459, 'left': 1176, 'top': 104, 'width': 52, 'height': 54, 'confidence': 0.96469414}
# {'frame': 1459, 'left': 650, 'top': 98, 'width': 42, 'height': 41, 'confidence': 0.9321014}
# {'frame': 1459, 'left': 901, 'top': 79, 'width': 113, 'height': 65, 'confidence': 0.8223188}
# {'frame': 1460, 'left': 1297, 'top': 361, 'width': 224, 'height': 175, 'confidence': 0.9952118}
# {'frame': 1460, 'left': 950, 'top': 258, 'width': 180, 'height': 150, 'confidence': 0.98510796}
# {'frame': 1460, 'left': 565, 'top': 94, 'width': 94, 'height': 71, 'confidence': 0.9847248}
# {'frame': 1460, 'left': 1178, 'top': 103, 'width': 50, 'height': 55, 'confidence': 0.96650934}
# {'frame': 1460, 'left': 653, 'top': 105, 'width': 41, 'height': 34, 'confidence': 0.9384444}
# {'frame': 1460, 'left': 899, 'top': 80, 'width': 116, 'height': 66, 'confidence': 0.82975465}
# {'frame': 1461, 'left': 1296, 'top': 361, 'width': 225, 'height': 175, 'confidence': 0.9949254}
# {'frame': 1461, 'left': 946, 'top': 253, 'width': 180, 'height': 149, 'confidence': 0.9892665}
# {'frame': 1461, 'left': 564, 'top': 94, 'width': 97, 'height': 71, 'confidence': 0.9746372}
# {'frame': 1461, 'left': 1178, 'top': 103, 'width': 50, 'height': 55, 'confidence': 0.96837974}
# {'frame': 1461, 'left': 653, 'top': 105, 'width': 40, 'height': 34, 'confidence': 0.9314625}
# {'frame': 1461, 'left': 904, 'top': 80, 'width': 110, 'height': 65, 'confidence': 0.9221854}
# {'frame': 1462, 'left': 1295, 'top': 361, 'width': 226, 'height': 175, 'confidence': 0.99497366}
# {'frame': 1462, 'left': 564, 'top': 95, 'width': 97, 'height': 71, 'confidence': 0.9743479}
# {'frame': 1462, 'left': 1177, 'top': 103, 'width': 50, 'height': 55, 'confidence': 0.9635754}
# {'frame': 1462, 'left': 654, 'top': 106, 'width': 40, 'height': 33, 'confidence': 0.9473374}
# {'frame': 1462, 'left': 939, 'top': 246, 'width': 185, 'height': 146, 'confidence': 0.9353411}
# {'frame': 1462, 'left': 902, 'top': 81, 'width': 111, 'height': 64, 'confidence': 0.91898286}
# {'frame': 1463, 'left': 1295, 'top': 361, 'width': 226, 'height': 175, 'confidence': 0.9945697}
# {'frame': 1463, 'left': 564, 'top': 94, 'width': 97, 'height': 72, 'confidence': 0.9756562}
# {'frame': 1463, 'left': 1176, 'top': 104, 'width': 52, 'height': 55, 'confidence': 0.9699064}
# {'frame': 1463, 'left': 653, 'top': 105, 'width': 42, 'height': 34, 'confidence': 0.9565772}
# {'frame': 1463, 'left': 937, 'top': 241, 'width': 183, 'height': 144, 'confidence': 0.9420918}
# {'frame': 1463, 'left': 903, 'top': 80, 'width': 112, 'height': 64, 'confidence': 0.9284395}
# {'frame': 1464, 'left': 1295, 'top': 361, 'width': 226, 'height': 174, 'confidence': 0.99407756}
# {'frame': 1464, 'left': 564, 'top': 94, 'width': 97, 'height': 72, 'confidence': 0.97221273}
# {'frame': 1464, 'left': 1177, 'top': 103, 'width': 51, 'height': 55, 'confidence': 0.9684294}
# {'frame': 1464, 'left': 653, 'top': 106, 'width': 41, 'height': 33, 'confidence': 0.9657001}
# {'frame': 1464, 'left': 932, 'top': 235, 'width': 185, 'height': 146, 'confidence': 0.94685596}
# {'frame': 1464, 'left': 903, 'top': 80, 'width': 111, 'height': 64, 'confidence': 0.92966264}
# {'frame': 1465, 'left': 1296, 'top': 360, 'width': 225, 'height': 176, 'confidence': 0.9929496}
# {'frame': 1465, 'left': 932, 'top': 232, 'width': 176, 'height': 145, 'confidence': 0.9804346}
# {'frame': 1465, 'left': 1177, 'top': 105, 'width': 51, 'height': 54, 'confidence': 0.9694317}
# {'frame': 1465, 'left': 563, 'top': 90, 'width': 97, 'height': 77, 'confidence': 0.9670506}
# {'frame': 1465, 'left': 653, 'top': 104, 'width': 41, 'height': 35, 'confidence': 0.94611335}
# {'frame': 1465, 'left': 899, 'top': 79, 'width': 115, 'height': 66, 'confidence': 0.918856}
# {'frame': 1466, 'left': 1296, 'top': 360, 'width': 225, 'height': 176, 'confidence': 0.9930594}
# {'frame': 1466, 'left': 933, 'top': 229, 'width': 178, 'height': 141, 'confidence': 0.9838388}
# {'frame': 1466, 'left': 1177, 'top': 105, 'width': 51, 'height': 54, 'confidence': 0.9658133}
# {'frame': 1466, 'left': 561, 'top': 89, 'width': 98, 'height': 78, 'confidence': 0.9588026}
# {'frame': 1466, 'left': 653, 'top': 102, 'width': 42, 'height': 38, 'confidence': 0.93601424}
# {'frame': 1466, 'left': 901, 'top': 79, 'width': 113, 'height': 66, 'confidence': 0.9160524}
# {'frame': 1467, 'left': 1296, 'top': 361, 'width': 225, 'height': 175, 'confidence': 0.9935183}
# {'frame': 1467, 'left': 933, 'top': 226, 'width': 169, 'height': 140, 'confidence': 0.98529714}
# {'frame': 1467, 'left': 1177, 'top': 105, 'width': 52, 'height': 54, 'confidence': 0.9704166}
# {'frame': 1467, 'left': 564, 'top': 93, 'width': 95, 'height': 73, 'confidence': 0.9478593}
# {'frame': 1467, 'left': 654, 'top': 105, 'width': 41, 'height': 35, 'confidence': 0.93291193}
# {'frame': 1467, 'left': 899, 'top': 81, 'width': 115, 'height': 65, 'confidence': 0.89255923}
# {'frame': 1468, 'left': 1296, 'top': 360, 'width': 226, 'height': 176, 'confidence': 0.9905468}
# {'frame': 1468, 'left': 1177, 'top': 105, 'width': 51, 'height': 55, 'confidence': 0.956535}
# {'frame': 1468, 'left': 928, 'top': 225, 'width': 170, 'height': 132, 'confidence': 0.955141}
# {'frame': 1468, 'left': 563, 'top': 93, 'width': 96, 'height': 73, 'confidence': 0.9499428}
# {'frame': 1468, 'left': 654, 'top': 104, 'width': 41, 'height': 36, 'confidence': 0.93226635}
# {'frame': 1468, 'left': 897, 'top': 82, 'width': 115, 'height': 63, 'confidence': 0.920163}
# {'frame': 1469, 'left': 1296, 'top': 361, 'width': 226, 'height': 175, 'confidence': 0.98981243}
# {'frame': 1469, 'left': 929, 'top': 222, 'width': 162, 'height': 131, 'confidence': 0.9760251}
# {'frame': 1469, 'left': 1177, 'top': 105, 'width': 51, 'height': 55, 'confidence': 0.9639012}
# {'frame': 1469, 'left': 563, 'top': 92, 'width': 95, 'height': 74, 'confidence': 0.9457483}
# {'frame': 1469, 'left': 900, 'top': 80, 'width': 114, 'height': 64, 'confidence': 0.9271585}
# {'frame': 1469, 'left': 653, 'top': 102, 'width': 42, 'height': 38, 'confidence': 0.90366906}
# {'frame': 1470, 'left': 1296, 'top': 361, 'width': 226, 'height': 174, 'confidence': 0.98944503}
# {'frame': 1470, 'left': 926, 'top': 214, 'width': 165, 'height': 135, 'confidence': 0.9796246}
# {'frame': 1470, 'left': 1177, 'top': 104, 'width': 51, 'height': 55, 'confidence': 0.97099394}
# {'frame': 1470, 'left': 564, 'top': 92, 'width': 95, 'height': 74, 'confidence': 0.9666072}
# {'frame': 1470, 'left': 654, 'top': 106, 'width': 42, 'height': 33, 'confidence': 0.94654477}
# {'frame': 1470, 'left': 901, 'top': 80, 'width': 112, 'height': 64, 'confidence': 0.926571}
# {'frame': 1470, 'left': 442, 'top': 135, 'width': 31, 'height': 37, 'confidence': 0.7029427}
# {'frame': 1471, 'left': 1297, 'top': 360, 'width': 225, 'height': 176, 'confidence': 0.9911937}
# {'frame': 1471, 'left': 924, 'top': 208, 'width': 165, 'height': 132, 'confidence': 0.99059}
# {'frame': 1471, 'left': 1177, 'top': 105, 'width': 51, 'height': 54, 'confidence': 0.96941996}
# {'frame': 1471, 'left': 564, 'top': 94, 'width': 96, 'height': 72, 'confidence': 0.9628655}
# {'frame': 1471, 'left': 903, 'top': 80, 'width': 110, 'height': 64, 'confidence': 0.9458886}
# {'frame': 1471, 'left': 654, 'top': 109, 'width': 43, 'height': 30, 'confidence': 0.907563}
# {'frame': 1471, 'left': 882, 'top': 90, 'width': 49, 'height': 49, 'confidence': 0.73436743}
# {'frame': 1472, 'left': 1297, 'top': 361, 'width': 225, 'height': 175, 'confidence': 0.99072814}
# {'frame': 1472, 'left': 920, 'top': 204, 'width': 161, 'height': 132, 'confidence': 0.9891817}
# {'frame': 1472, 'left': 1177, 'top': 105, 'width': 51, 'height': 52, 'confidence': 0.9637864}
# {'frame': 1472, 'left': 563, 'top': 93, 'width': 97, 'height': 73, 'confidence': 0.9620439}
# {'frame': 1472, 'left': 903, 'top': 80, 'width': 110, 'height': 64, 'confidence': 0.9510668}
# {'frame': 1472, 'left': 654, 'top': 107, 'width': 44, 'height': 33, 'confidence': 0.9039762}
# {'frame': 1472, 'left': 881, 'top': 90, 'width': 49, 'height': 49, 'confidence': 0.7580142}
# {'frame': 1473, 'left': 920, 'top': 202, 'width': 160, 'height': 128, 'confidence': 0.99572194}
# {'frame': 1473, 'left': 1296, 'top': 361, 'width': 226, 'height': 175, 'confidence': 0.99079}
# {'frame': 1473, 'left': 563, 'top': 92, 'width': 97, 'height': 74, 'confidence': 0.9605258}
# {'frame': 1473, 'left': 1177, 'top': 105, 'width': 51, 'height': 52, 'confidence': 0.9585964}
# {'frame': 1473, 'left': 901, 'top': 79, 'width': 113, 'height': 65, 'confidence': 0.95450693}
# {'frame': 1473, 'left': 656, 'top': 113, 'width': 48, 'height': 28, 'confidence': 0.91307}
# {'frame': 1473, 'left': 881, 'top': 90, 'width': 49, 'height': 49, 'confidence': 0.7242444}
# {'frame': 1474, 'left': 1296, 'top': 361, 'width': 226, 'height': 175, 'confidence': 0.99020165}
# {'frame': 1474, 'left': 919, 'top': 201, 'width': 157, 'height': 124, 'confidence': 0.9797227}
# {'frame': 1474, 'left': 564, 'top': 93, 'width': 97, 'height': 73, 'confidence': 0.9623523}
# {'frame': 1474, 'left': 1177, 'top': 105, 'width': 52, 'height': 52, 'confidence': 0.9517286}
# {'frame': 1474, 'left': 903, 'top': 79, 'width': 112, 'height': 65, 'confidence': 0.94418544}
# {'frame': 1474, 'left': 654, 'top': 109, 'width': 50, 'height': 31, 'confidence': 0.9264291}
# {'frame': 1474, 'left': 882, 'top': 90, 'width': 48, 'height': 49, 'confidence': 0.729429}
# {'frame': 1475, 'left': 1297, 'top': 362, 'width': 225, 'height': 174, 'confidence': 0.9900573}
# {'frame': 1475, 'left': 918, 'top': 196, 'width': 157, 'height': 123, 'confidence': 0.96966547}
# {'frame': 1475, 'left': 564, 'top': 93, 'width': 97, 'height': 73, 'confidence': 0.96482164}
# {'frame': 1475, 'left': 1177, 'top': 105, 'width': 52, 'height': 53, 'confidence': 0.96317434}
# {'frame': 1475, 'left': 903, 'top': 79, 'width': 112, 'height': 65, 'confidence': 0.9488918}
# {'frame': 1475, 'left': 652, 'top': 99, 'width': 54, 'height': 42, 'confidence': 0.8372231}
# {'frame': 1475, 'left': 880, 'top': 89, 'width': 52, 'height': 50, 'confidence': 0.7112898}
# {'frame': 1476, 'left': 1297, 'top': 361, 'width': 225, 'height': 175, 'confidence': 0.9903216}
# {'frame': 1476, 'left': 564, 'top': 93, 'width': 97, 'height': 73, 'confidence': 0.9646631}
# {'frame': 1476, 'left': 1177, 'top': 105, 'width': 51, 'height': 53, 'confidence': 0.9564168}
# {'frame': 1476, 'left': 900, 'top': 79, 'width': 115, 'height': 65, 'confidence': 0.94725734}
# {'frame': 1476, 'left': 915, 'top': 193, 'width': 153, 'height': 123, 'confidence': 0.9137277}
# {'frame': 1476, 'left': 652, 'top': 102, 'width': 55, 'height': 39, 'confidence': 0.8658568}
# {'frame': 1477, 'left': 1296, 'top': 360, 'width': 228, 'height': 177, 'confidence': 0.9929646}
# {'frame': 1477, 'left': 913, 'top': 188, 'width': 153, 'height': 121, 'confidence': 0.98322475}
# {'frame': 1477, 'left': 1177, 'top': 104, 'width': 51, 'height': 55, 'confidence': 0.9619295}
# {'frame': 1477, 'left': 564, 'top': 93, 'width': 95, 'height': 73, 'confidence': 0.9513408}
# {'frame': 1477, 'left': 897, 'top': 81, 'width': 118, 'height': 63, 'confidence': 0.94615155}
# {'frame': 1477, 'left': 655, 'top': 111, 'width': 46, 'height': 30, 'confidence': 0.900295}
# {'frame': 1478, 'left': 911, 'top': 183, 'width': 153, 'height': 120, 'confidence': 0.99404526}
# {'frame': 1478, 'left': 1296, 'top': 360, 'width': 228, 'height': 177, 'confidence': 0.993001}
# {'frame': 1478, 'left': 1177, 'top': 104, 'width': 51, 'height': 55, 'confidence': 0.9665775}
# {'frame': 1478, 'left': 564, 'top': 92, 'width': 95, 'height': 74, 'confidence': 0.95599884}
# {'frame': 1478, 'left': 898, 'top': 81, 'width': 117, 'height': 63, 'confidence': 0.944656}
# {'frame': 1478, 'left': 655, 'top': 110, 'width': 49, 'height': 30, 'confidence': 0.9214009}
# {'frame': 1479, 'left': 911, 'top': 181, 'width': 150, 'height': 116, 'confidence': 0.99314415}
# {'frame': 1479, 'left': 1295, 'top': 359, 'width': 229, 'height': 178, 'confidence': 0.99096256}
# {'frame': 1479, 'left': 563, 'top': 93, 'width': 98, 'height': 73, 'confidence': 0.9610223}
# {'frame': 1479, 'left': 1176, 'top': 104, 'width': 52, 'height': 54, 'confidence': 0.9553392}
# {'frame': 1479, 'left': 904, 'top': 79, 'width': 110, 'height': 65, 'confidence': 0.9552031}
# {'frame': 1479, 'left': 655, 'top': 109, 'width': 50, 'height': 31, 'confidence': 0.9067554}
# {'frame': 1480, 'left': 1294, 'top': 362, 'width': 228, 'height': 174, 'confidence': 0.9893413}
# {'frame': 1480, 'left': 906, 'top': 180, 'width': 150, 'height': 114, 'confidence': 0.98830086}
# {'frame': 1480, 'left': 905, 'top': 79, 'width': 110, 'height': 65, 'confidence': 0.9634189}
# {'frame': 1480, 'left': 1176, 'top': 104, 'width': 52, 'height': 54, 'confidence': 0.95825964}
# {'frame': 1480, 'left': 564, 'top': 94, 'width': 97, 'height': 72, 'confidence': 0.9535827}
# {'frame': 1480, 'left': 652, 'top': 100, 'width': 53, 'height': 39, 'confidence': 0.8749222}
# {'frame': 1480, 'left': 544, 'top': 112, 'width': 29, 'height': 44, 'confidence': 0.7285957}
# {'frame': 1481, 'left': 905, 'top': 175, 'width': 149, 'height': 117, 'confidence': 0.9931005}
# {'frame': 1481, 'left': 1294, 'top': 360, 'width': 227, 'height': 176, 'confidence': 0.9921463}
# {'frame': 1481, 'left': 902, 'top': 79, 'width': 113, 'height': 66, 'confidence': 0.9586389}
# {'frame': 1481, 'left': 564, 'top': 91, 'width': 97, 'height': 75, 'confidence': 0.9504504}
# {'frame': 1481, 'left': 1176, 'top': 105, 'width': 52, 'height': 52, 'confidence': 0.9455783}
# {'frame': 1481, 'left': 654, 'top': 101, 'width': 56, 'height': 40, 'confidence': 0.9179794}
# {'frame': 1481, 'left': 878, 'top': 89, 'width': 56, 'height': 50, 'confidence': 0.7047695}
# {'frame': 1481, 'left': 441, 'top': 133, 'width': 32, 'height': 41, 'confidence': 0.7020193}
# {'frame': 1482, 'left': 1295, 'top': 361, 'width': 226, 'height': 174, 'confidence': 0.9938501}
# {'frame': 1482, 'left': 905, 'top': 172, 'width': 145, 'height': 116, 'confidence': 0.99207073}
# {'frame': 1482, 'left': 899, 'top': 79, 'width': 117, 'height': 66, 'confidence': 0.9562917}
# {'frame': 1482, 'left': 1176, 'top': 104, 'width': 52, 'height': 53, 'confidence': 0.947949}
# {'frame': 1482, 'left': 564, 'top': 92, 'width': 98, 'height': 74, 'confidence': 0.9344823}
# {'frame': 1482, 'left': 657, 'top': 109, 'width': 54, 'height': 32, 'confidence': 0.8883353}
# {'frame': 1482, 'left': 441, 'top': 135, 'width': 32, 'height': 38, 'confidence': 0.7270225}
# {'frame': 1483, 'left': 1295, 'top': 361, 'width': 226, 'height': 174, 'confidence': 0.99354964}
# {'frame': 1483, 'left': 902, 'top': 162, 'width': 144, 'height': 118, 'confidence': 0.98890895}
# {'frame': 1483, 'left': 1176, 'top': 104, 'width': 52, 'height': 53, 'confidence': 0.9526765}
# {'frame': 1483, 'left': 910, 'top': 78, 'width': 106, 'height': 69, 'confidence': 0.94569254}
# {'frame': 1483, 'left': 565, 'top': 92, 'width': 98, 'height': 74, 'confidence': 0.945609}
# {'frame': 1483, 'left': 656, 'top': 105, 'width': 55, 'height': 36, 'confidence': 0.82317615}
# {'frame': 1483, 'left': 441, 'top': 135, 'width': 32, 'height': 38, 'confidence': 0.7748162}
# {'frame': 1484, 'left': 902, 'top': 160, 'width': 144, 'height': 116, 'confidence': 0.9950826}
# {'frame': 1484, 'left': 1295, 'top': 362, 'width': 227, 'height': 174, 'confidence': 0.9920129}
# {'frame': 1484, 'left': 1176, 'top': 104, 'width': 53, 'height': 52, 'confidence': 0.95976007}
# {'frame': 1484, 'left': 566, 'top': 92, 'width': 95, 'height': 73, 'confidence': 0.9558869}
# {'frame': 1484, 'left': 916, 'top': 78, 'width': 100, 'height': 70, 'confidence': 0.9546053}
# {'frame': 1484, 'left': 656, 'top': 106, 'width': 56, 'height': 34, 'confidence': 0.9327215}
# {'frame': 1484, 'left': 441, 'top': 136, 'width': 32, 'height': 37, 'confidence': 0.79436064}
# {'frame': 1485, 'left': 899, 'top': 163, 'width': 144, 'height': 109, 'confidence': 0.99430555}
# {'frame': 1485, 'left': 1296, 'top': 361, 'width': 226, 'height': 175, 'confidence': 0.99215746}
# {'frame': 1485, 'left': 654, 'top': 100, 'width': 56, 'height': 40, 'confidence': 0.9679328}
# {'frame': 1485, 'left': 565, 'top': 93, 'width': 97, 'height': 72, 'confidence': 0.9620737}
# {'frame': 1485, 'left': 1176, 'top': 104, 'width': 53, 'height': 53, 'confidence': 0.96137637}
# {'frame': 1485, 'left': 914, 'top': 79, 'width': 103, 'height': 67, 'confidence': 0.9369541}
# {'frame': 1485, 'left': 441, 'top': 136, 'width': 33, 'height': 37, 'confidence': 0.82243776}
# {'frame': 1485, 'left': 544, 'top': 114, 'width': 28, 'height': 38, 'confidence': 0.71964526}
# {'frame': 1486, 'left': 897, 'top': 155, 'width': 140, 'height': 114, 'confidence': 0.99582857}
# {'frame': 1486, 'left': 1296, 'top': 361, 'width': 225, 'height': 175, 'confidence': 0.9928387}
# {'frame': 1486, 'left': 654, 'top': 103, 'width': 59, 'height': 37, 'confidence': 0.97515786}
# {'frame': 1486, 'left': 565, 'top': 94, 'width': 97, 'height': 71, 'confidence': 0.9614824}
# {'frame': 1486, 'left': 1176, 'top': 105, 'width': 53, 'height': 51, 'confidence': 0.9564702}
# {'frame': 1486, 'left': 912, 'top': 78, 'width': 104, 'height': 70, 'confidence': 0.94672626}
# {'frame': 1486, 'left': 440, 'top': 136, 'width': 34, 'height': 37, 'confidence': 0.808427}
# {'frame': 1486, 'left': 544, 'top': 115, 'width': 27, 'height': 36, 'confidence': 0.78112}
# {'frame': 1487, 'left': 1295, 'top': 359, 'width': 227, 'height': 178, 'confidence': 0.9917379}
# {'frame': 1487, 'left': 897, 'top': 156, 'width': 139, 'height': 108, 'confidence': 0.9907206}
# {'frame': 1487, 'left': 1178, 'top': 105, 'width': 51, 'height': 53, 'confidence': 0.9701716}
# {'frame': 1487, 'left': 567, 'top': 93, 'width': 94, 'height': 73, 'confidence': 0.96110046}
# {'frame': 1487, 'left': 656, 'top': 105, 'width': 57, 'height': 34, 'confidence': 0.93305534}
# {'frame': 1487, 'left': 906, 'top': 77, 'width': 112, 'height': 71, 'confidence': 0.90475404}
# {'frame': 1487, 'left': 544, 'top': 115, 'width': 28, 'height': 40, 'confidence': 0.7086759}
# {'frame': 1488, 'left': 894, 'top': 155, 'width': 142, 'height': 108, 'confidence': 0.9939148}
# {'frame': 1488, 'left': 1295, 'top': 359, 'width': 227, 'height': 178, 'confidence': 0.99187547}
# {'frame': 1488, 'left': 1178, 'top': 104, 'width': 51, 'height': 54, 'confidence': 0.9697337}
# {'frame': 1488, 'left': 566, 'top': 93, 'width': 94, 'height': 73, 'confidence': 0.9590692}
# {'frame': 1488, 'left': 657, 'top': 105, 'width': 57, 'height': 34, 'confidence': 0.91908246}
# {'frame': 1488, 'left': 900, 'top': 78, 'width': 117, 'height': 67, 'confidence': 0.9147167}
# {'frame': 1488, 'left': 544, 'top': 115, 'width': 29, 'height': 41, 'confidence': 0.7376866}
# {'frame': 1489, 'left': 895, 'top': 154, 'width': 136, 'height': 107, 'confidence': 0.992187}
# {'frame': 1489, 'left': 1297, 'top': 361, 'width': 225, 'height': 175, 'confidence': 0.99154246}
# {'frame': 1489, 'left': 1178, 'top': 104, 'width': 51, 'height': 54, 'confidence': 0.9751898}
# {'frame': 1489, 'left': 566, 'top': 94, 'width': 95, 'height': 71, 'confidence': 0.95881224}
# {'frame': 1489, 'left': 901, 'top': 79, 'width': 118, 'height': 67, 'confidence': 0.94194806}
# {'frame': 1489, 'left': 657, 'top': 102, 'width': 57, 'height': 37, 'confidence': 0.91004974}
# {'frame': 1489, 'left': 880, 'top': 91, 'width': 53, 'height': 49, 'confidence': 0.7310027}
# {'frame': 1489, 'left': 545, 'top': 116, 'width': 27, 'height': 40, 'confidence': 0.7128395}
# {'frame': 1490, 'left': 891, 'top': 152, 'width': 140, 'height': 106, 'confidence': 0.99374616}
# {'frame': 1490, 'left': 1297, 'top': 361, 'width': 225, 'height': 175, 'confidence': 0.9899861}
# {'frame': 1490, 'left': 1178, 'top': 104, 'width': 51, 'height': 54, 'confidence': 0.9765212}
# {'frame': 1490, 'left': 566, 'top': 94, 'width': 94, 'height': 71, 'confidence': 0.96063703}
# {'frame': 1490, 'left': 908, 'top': 79, 'width': 111, 'height': 67, 'confidence': 0.9348023}
# {'frame': 1490, 'left': 655, 'top': 101, 'width': 59, 'height': 37, 'confidence': 0.9260981}
# {'frame': 1490, 'left': 881, 'top': 91, 'width': 51, 'height': 49, 'confidence': 0.7948624}
# {'frame': 1491, 'left': 894, 'top': 151, 'width': 130, 'height': 104, 'confidence': 0.9967403}
# {'frame': 1491, 'left': 1297, 'top': 361, 'width': 225, 'height': 175, 'confidence': 0.9884276}
# {'frame': 1491, 'left': 1178, 'top': 104, 'width': 51, 'height': 54, 'confidence': 0.97750413}
# {'frame': 1491, 'left': 566, 'top': 95, 'width': 94, 'height': 70, 'confidence': 0.9663199}
# {'frame': 1491, 'left': 656, 'top': 103, 'width': 59, 'height': 36, 'confidence': 0.94414294}
# {'frame': 1491, 'left': 912, 'top': 80, 'width': 108, 'height': 68, 'confidence': 0.93605936}
# {'frame': 1491, 'left': 880, 'top': 91, 'width': 52, 'height': 49, 'confidence': 0.8006261}
# {'frame': 1492, 'left': 889, 'top': 149, 'width': 136, 'height': 102, 'confidence': 0.9935249}
# {'frame': 1492, 'left': 1296, 'top': 360, 'width': 226, 'height': 176, 'confidence': 0.98824245}
# {'frame': 1492, 'left': 1178, 'top': 104, 'width': 51, 'height': 54, 'confidence': 0.9763749}
# {'frame': 1492, 'left': 566, 'top': 94, 'width': 93, 'height': 71, 'confidence': 0.9707324}
# {'frame': 1492, 'left': 654, 'top': 91, 'width': 62, 'height': 49, 'confidence': 0.9144592}
# {'frame': 1492, 'left': 915, 'top': 78, 'width': 103, 'height': 71, 'confidence': 0.87803084}
# {'frame': 1492, 'left': 877, 'top': 94, 'width': 53, 'height': 47, 'confidence': 0.75598514}
# {'frame': 1493, 'left': 889, 'top': 148, 'width': 128, 'height': 102, 'confidence': 0.99624324}
# {'frame': 1493, 'left': 1296, 'top': 360, 'width': 225, 'height': 176, 'confidence': 0.98965424}
# {'frame': 1493, 'left': 1178, 'top': 104, 'width': 51, 'height': 54, 'confidence': 0.97436327}
# {'frame': 1493, 'left': 565, 'top': 93, 'width': 94, 'height': 72, 'confidence': 0.9651187}
# {'frame': 1493, 'left': 654, 'top': 85, 'width': 64, 'height': 56, 'confidence': 0.8864508}
# {'frame': 1493, 'left': 911, 'top': 80, 'width': 109, 'height': 67, 'confidence': 0.83882684}
# {'frame': 1494, 'left': 887, 'top': 144, 'width': 128, 'height': 97, 'confidence': 0.9960526}
# {'frame': 1494, 'left': 1296, 'top': 360, 'width': 226, 'height': 176, 'confidence': 0.9896344}
# {'frame': 1494, 'left': 1178, 'top': 104, 'width': 51, 'height': 54, 'confidence': 0.97185135}
# {'frame': 1494, 'left': 566, 'top': 93, 'width': 93, 'height': 72, 'confidence': 0.95494354}
# {'frame': 1494, 'left': 654, 'top': 87, 'width': 64, 'height': 53, 'confidence': 0.895695}
# {'frame': 1494, 'left': 911, 'top': 81, 'width': 106, 'height': 64, 'confidence': 0.86948717}
# ...
# {'frame': 2116, 'left': 1291, 'top': 361, 'width': 232, 'height': 178, 'confidence': 0.99446374}
# {'frame': 2116, 'left': 562, 'top': 96, 'width': 98, 'height': 68, 'confidence': 0.9520202}
# {'frame': 2116, 'left': 887, 'top': 86, 'width': 132, 'height': 57, 'confidence': 0.9184859}
# {'frame': 2116, 'left': 1003, 'top': 93, 'width': 35, 'height': 50, 'confidence': 0.84704775}
# {'frame': 2116, 'left': 1180, 'top': 104, 'width': 50, 'height': 49, 'confidence': 0.83268106}
# {'frame': 2116, 'left': 545, 'top': 116, 'width': 25, 'height': 43, 'confidence': 0.7488553}
# {'frame': 2117, 'left': 951, 'top': 163, 'width': 127, 'height': 103, 'confidence': 0.99694425}
# {'frame': 2117, 'left': 1291, 'top': 361, 'width': 232, 'height': 178, 'confidence': 0.9936929}
# {'frame': 2117, 'left': 561, 'top': 95, 'width': 100, 'height': 70, 'confidence': 0.9501717}
# {'frame': 2117, 'left': 917, 'top': 82, 'width': 103, 'height': 62, 'confidence': 0.9219213}
# {'frame': 2117, 'left': 1180, 'top': 103, 'width': 50, 'height': 51, 'confidence': 0.8635787}
# {'frame': 2117, 'left': 1006, 'top': 93, 'width': 32, 'height': 49, 'confidence': 0.812276}
# {'frame': 2118, 'left': 948, 'top': 159, 'width': 128, 'height': 107, 'confidence': 0.99637955}
# {'frame': 2118, 'left': 1291, 'top': 361, 'width': 232, 'height': 178, 'confidence': 0.99361813}
# {'frame': 2118, 'left': 904, 'top': 82, 'width': 117, 'height': 61, 'confidence': 0.9472821}
# {'frame': 2118, 'left': 560, 'top': 92, 'width': 102, 'height': 74, 'confidence': 0.94694835}
# {'frame': 2118, 'left': 1180, 'top': 103, 'width': 50, 'height': 51, 'confidence': 0.8636545}
# {'frame': 2118, 'left': 544, 'top': 116, 'width': 26, 'height': 43, 'confidence': 0.78115433}
# {'frame': 2118, 'left': 1004, 'top': 94, 'width': 34, 'height': 49, 'confidence': 0.7508891}
# {'frame': 2119, 'left': 950, 'top': 156, 'width': 118, 'height': 106, 'confidence': 0.9959188}
# {'frame': 2119, 'left': 1291, 'top': 361, 'width': 232, 'height': 178, 'confidence': 0.9940242}
# {'frame': 2119, 'left': 562, 'top': 93, 'width': 99, 'height': 72, 'confidence': 0.9456625}
# {'frame': 2119, 'left': 905, 'top': 83, 'width': 113, 'height': 61, 'confidence': 0.93572426}
# {'frame': 2119, 'left': 1178, 'top': 103, 'width': 53, 'height': 53, 'confidence': 0.87382334}
# {'frame': 2119, 'left': 544, 'top': 117, 'width': 27, 'height': 43, 'confidence': 0.8683426}
# {'frame': 2119, 'left': 1005, 'top': 95, 'width': 33, 'height': 48, 'confidence': 0.8018548}
# {'frame': 2120, 'left': 947, 'top': 156, 'width': 125, 'height': 104, 'confidence': 0.995204}
# {'frame': 2120, 'left': 1291, 'top': 360, 'width': 232, 'height': 179, 'confidence': 0.99353904}
# {'frame': 2120, 'left': 905, 'top': 82, 'width': 114, 'height': 62, 'confidence': 0.9518276}
# {'frame': 2120, 'left': 562, 'top': 93, 'width': 99, 'height': 72, 'confidence': 0.9298097}
# {'frame': 2120, 'left': 1178, 'top': 103, 'width': 53, 'height': 53, 'confidence': 0.87774956}
# {'frame': 2120, 'left': 1005, 'top': 96, 'width': 33, 'height': 46, 'confidence': 0.8591504}
# {'frame': 2120, 'left': 544, 'top': 117, 'width': 27, 'height': 43, 'confidence': 0.8549856}
# {'frame': 2121, 'left': 943, 'top': 152, 'width': 125, 'height': 102, 'confidence': 0.9961676}
# {'frame': 2121, 'left': 1291, 'top': 360, 'width': 232, 'height': 179, 'confidence': 0.9934883}
# {'frame': 2121, 'left': 909, 'top': 83, 'width': 110, 'height': 61, 'confidence': 0.9590799}
# {'frame': 2121, 'left': 563, 'top': 93, 'width': 98, 'height': 72, 'confidence': 0.93387437}
# {'frame': 2121, 'left': 544, 'top': 117, 'width': 28, 'height': 42, 'confidence': 0.881879}
# {'frame': 2121, 'left': 1178, 'top': 103, 'width': 53, 'height': 53, 'confidence': 0.8772304}
# {'frame': 2121, 'left': 1004, 'top': 96, 'width': 34, 'height': 49, 'confidence': 0.8196523}
# {'frame': 2122, 'left': 1291, 'top': 360, 'width': 232, 'height': 179, 'confidence': 0.99324435}
# {'frame': 2122, 'left': 944, 'top': 154, 'width': 119, 'height': 99, 'confidence': 0.9927994}
# {'frame': 2122, 'left': 563, 'top': 92, 'width': 99, 'height': 73, 'confidence': 0.9355481}
# {'frame': 2122, 'left': 917, 'top': 84, 'width': 103, 'height': 59, 'confidence': 0.929959}
# {'frame': 2122, 'left': 1178, 'top': 103, 'width': 53, 'height': 53, 'confidence': 0.8712177}
# {'frame': 2122, 'left': 544, 'top': 117, 'width': 27, 'height': 42, 'confidence': 0.85940766}
# {'frame': 2122, 'left': 1004, 'top': 96, 'width': 34, 'height': 46, 'confidence': 0.83231217}
# {'frame': 2123, 'left': 943, 'top': 150, 'width': 118, 'height': 99, 'confidence': 0.9944265}
# {'frame': 2123, 'left': 1296, 'top': 363, 'width': 227, 'height': 173, 'confidence': 0.99260134}
# {'frame': 2123, 'left': 913, 'top': 83, 'width': 104, 'height': 60, 'confidence': 0.93628937}
# {'frame': 2123, 'left': 563, 'top': 93, 'width': 99, 'height': 72, 'confidence': 0.91742766}
# {'frame': 2123, 'left': 1179, 'top': 103, 'width': 52, 'height': 52, 'confidence': 0.8595146}
# {'frame': 2123, 'left': 544, 'top': 117, 'width': 27, 'height': 41, 'confidence': 0.85834473}
# {'frame': 2123, 'left': 1005, 'top': 97, 'width': 31, 'height': 46, 'confidence': 0.83793443}
# {'frame': 2124, 'left': 940, 'top': 149, 'width': 120, 'height': 95, 'confidence': 0.9947379}
# {'frame': 2124, 'left': 1296, 'top': 363, 'width': 226, 'height': 172, 'confidence': 0.9936417}
# {'frame': 2124, 'left': 563, 'top': 94, 'width': 98, 'height': 71, 'confidence': 0.94099796}
# {'frame': 2124, 'left': 916, 'top': 83, 'width': 101, 'height': 61, 'confidence': 0.9122575}
# {'frame': 2124, 'left': 1178, 'top': 104, 'width': 52, 'height': 53, 'confidence': 0.8843171}
# {'frame': 2124, 'left': 544, 'top': 117, 'width': 27, 'height': 41, 'confidence': 0.85349315}
# {'frame': 2124, 'left': 1005, 'top': 97, 'width': 32, 'height': 47, 'confidence': 0.8306904}
# {'frame': 2125, 'left': 1293, 'top': 361, 'width': 229, 'height': 177, 'confidence': 0.99352515}
# {'frame': 2125, 'left': 936, 'top': 147, 'width': 120, 'height': 98, 'confidence': 0.98826945}
# {'frame': 2125, 'left': 562, 'top': 92, 'width': 99, 'height': 73, 'confidence': 0.93695474}
# {'frame': 2125, 'left': 923, 'top': 82, 'width': 97, 'height': 62, 'confidence': 0.9358011}
# {'frame': 2125, 'left': 1177, 'top': 103, 'width': 53, 'height': 54, 'confidence': 0.9317987}
# {'frame': 2125, 'left': 544, 'top': 117, 'width': 27, 'height': 39, 'confidence': 0.8186827}
# {'frame': 2125, 'left': 1005, 'top': 95, 'width': 32, 'height': 49, 'confidence': 0.8102333}
# {'frame': 2126, 'left': 1293, 'top': 360, 'width': 229, 'height': 178, 'confidence': 0.9933015}
# {'frame': 2126, 'left': 934, 'top': 148, 'width': 119, 'height': 91, 'confidence': 0.98610085}
# {'frame': 2126, 'left': 562, 'top': 92, 'width': 100, 'height': 72, 'confidence': 0.94610524}
# {'frame': 2126, 'left': 920, 'top': 82, 'width': 98, 'height': 62, 'confidence': 0.9336857}
# {'frame': 2126, 'left': 1177, 'top': 103, 'width': 53, 'height': 55, 'confidence': 0.9336659}
# {'frame': 2126, 'left': 544, 'top': 117, 'width': 27, 'height': 39, 'confidence': 0.83561367}
# {'frame': 2126, 'left': 1005, 'top': 96, 'width': 32, 'height': 48, 'confidence': 0.831811}
# {'frame': 2127, 'left': 1293, 'top': 360, 'width': 229, 'height': 178, 'confidence': 0.9932775}
# {'frame': 2127, 'left': 934, 'top': 147, 'width': 115, 'height': 89, 'confidence': 0.97846013}
# {'frame': 2127, 'left': 562, 'top': 92, 'width': 100, 'height': 73, 'confidence': 0.93349385}
# {'frame': 2127, 'left': 926, 'top': 82, 'width': 92, 'height': 62, 'confidence': 0.9327967}
# {'frame': 2127, 'left': 1178, 'top': 103, 'width': 52, 'height': 55, 'confidence': 0.9099103}
# {'frame': 2127, 'left': 1003, 'top': 95, 'width': 36, 'height': 49, 'confidence': 0.8804482}
# {'frame': 2127, 'left': 544, 'top': 118, 'width': 27, 'height': 40, 'confidence': 0.86076415}
# {'frame': 2128, 'left': 1294, 'top': 360, 'width': 228, 'height': 178, 'confidence': 0.9922693}
# {'frame': 2128, 'left': 932, 'top': 141, 'width': 115, 'height': 94, 'confidence': 0.9804063}
# {'frame': 2128, 'left': 926, 'top': 83, 'width': 93, 'height': 59, 'confidence': 0.9478043}
# {'frame': 2128, 'left': 562, 'top': 93, 'width': 100, 'height': 72, 'confidence': 0.93310994}
# {'frame': 2128, 'left': 1178, 'top': 103, 'width': 53, 'height': 56, 'confidence': 0.92008823}
# {'frame': 2128, 'left': 544, 'top': 117, 'width': 27, 'height': 41, 'confidence': 0.8751485}
# {'frame': 2128, 'left': 1002, 'top': 95, 'width': 37, 'height': 49, 'confidence': 0.8437696}
# {'frame': 2129, 'left': 1294, 'top': 359, 'width': 228, 'height': 179, 'confidence': 0.991691}
# {'frame': 2129, 'left': 563, 'top': 92, 'width': 99, 'height': 73, 'confidence': 0.94927573}
# {'frame': 2129, 'left': 931, 'top': 139, 'width': 111, 'height': 95, 'confidence': 0.9447986}
# {'frame': 2129, 'left': 926, 'top': 82, 'width': 94, 'height': 62, 'confidence': 0.93531364}
# {'frame': 2129, 'left': 1178, 'top': 103, 'width': 52, 'height': 55, 'confidence': 0.9266904}
# {'frame': 2129, 'left': 544, 'top': 117, 'width': 27, 'height': 41, 'confidence': 0.8565435}
# {'frame': 2129, 'left': 1004, 'top': 96, 'width': 33, 'height': 48, 'confidence': 0.81777805}
# {'frame': 2130, 'left': 1296, 'top': 362, 'width': 227, 'height': 173, 'confidence': 0.9896623}
# {'frame': 2130, 'left': 563, 'top': 93, 'width': 99, 'height': 71, 'confidence': 0.9530016}
# {'frame': 2130, 'left': 1178, 'top': 103, 'width': 52, 'height': 57, 'confidence': 0.91466326}
# {'frame': 2130, 'left': 928, 'top': 83, 'width': 94, 'height': 58, 'confidence': 0.86392844}
# {'frame': 2130, 'left': 544, 'top': 117, 'width': 27, 'height': 38, 'confidence': 0.81308496}
# {'frame': 2130, 'left': 1004, 'top': 97, 'width': 33, 'height': 47, 'confidence': 0.77591175}
# {'frame': 2131, 'left': 1296, 'top': 362, 'width': 227, 'height': 173, 'confidence': 0.99114764}
# {'frame': 2131, 'left': 563, 'top': 93, 'width': 99, 'height': 71, 'confidence': 0.9434641}
# {'frame': 2131, 'left': 1178, 'top': 103, 'width': 51, 'height': 54, 'confidence': 0.92951334}
# {'frame': 2131, 'left': 544, 'top': 117, 'width': 27, 'height': 42, 'confidence': 0.86156094}
# {'frame': 2131, 'left': 929, 'top': 82, 'width': 97, 'height': 59, 'confidence': 0.81139505}
# {'frame': 2132, 'left': 1295, 'top': 363, 'width': 227, 'height': 172, 'confidence': 0.9917446}
# {'frame': 2132, 'left': 563, 'top': 94, 'width': 98, 'height': 70, 'confidence': 0.9349656}
# {'frame': 2132, 'left': 1178, 'top': 103, 'width': 52, 'height': 56, 'confidence': 0.9240081}
# {'frame': 2132, 'left': 544, 'top': 117, 'width': 27, 'height': 41, 'confidence': 0.8868498}
# {'frame': 2132, 'left': 919, 'top': 84, 'width': 113, 'height': 58, 'confidence': 0.84029925}
# {'frame': 2133, 'left': 1296, 'top': 363, 'width': 227, 'height': 172, 'confidence': 0.9923586}
# {'frame': 2133, 'left': 563, 'top': 94, 'width': 98, 'height': 70, 'confidence': 0.9457368}
# {'frame': 2133, 'left': 1177, 'top': 104, 'width': 53, 'height': 53, 'confidence': 0.93785936}
# {'frame': 2133, 'left': 544, 'top': 117, 'width': 27, 'height': 40, 'confidence': 0.903731}
# {'frame': 2133, 'left': 926, 'top': 134, 'width': 107, 'height': 84, 'confidence': 0.8667807}
# {'frame': 2133, 'left': 931, 'top': 83, 'width': 90, 'height': 56, 'confidence': 0.8517685}
# {'frame': 2133, 'left': 1004, 'top': 98, 'width': 33, 'height': 45, 'confidence': 0.7363035}
# {'frame': 2133, 'left': 443, 'top': 138, 'width': 30, 'height': 35, 'confidence': 0.70133215}
# {'frame': 2134, 'left': 1294, 'top': 363, 'width': 228, 'height': 173, 'confidence': 0.9904371}
# {'frame': 2134, 'left': 563, 'top': 93, 'width': 97, 'height': 71, 'confidence': 0.9370333}
# {'frame': 2134, 'left': 1178, 'top': 102, 'width': 52, 'height': 55, 'confidence': 0.8803142}
# {'frame': 2134, 'left': 544, 'top': 117, 'width': 27, 'height': 39, 'confidence': 0.87312305}
# {'frame': 2134, 'left': 931, 'top': 82, 'width': 89, 'height': 55, 'confidence': 0.8438257}
# {'frame': 2134, 'left': 925, 'top': 133, 'width': 105, 'height': 84, 'confidence': 0.78537756}
# {'frame': 2135, 'left': 1294, 'top': 363, 'width': 228, 'height': 174, 'confidence': 0.99416673}
# {'frame': 2135, 'left': 922, 'top': 130, 'width': 107, 'height': 84, 'confidence': 0.9791099}
# {'frame': 2135, 'left': 931, 'top': 82, 'width': 87, 'height': 54, 'confidence': 0.9213461}
# {'frame': 2135, 'left': 564, 'top': 94, 'width': 97, 'height': 69, 'confidence': 0.90655977}
# {'frame': 2135, 'left': 1178, 'top': 104, 'width': 51, 'height': 56, 'confidence': 0.86751086}
# {'frame': 2135, 'left': 544, 'top': 117, 'width': 26, 'height': 40, 'confidence': 0.86730397}
# {'frame': 2135, 'left': 443, 'top': 135, 'width': 30, 'height': 38, 'confidence': 0.8113794}
# {'frame': 2136, 'left': 1293, 'top': 364, 'width': 228, 'height': 172, 'confidence': 0.9941175}
# {'frame': 2136, 'left': 921, 'top': 131, 'width': 105, 'height': 82, 'confidence': 0.9642148}
# {'frame': 2136, 'left': 925, 'top': 84, 'width': 96, 'height': 55, 'confidence': 0.9005646}
# {'frame': 2136, 'left': 543, 'top': 117, 'width': 28, 'height': 40, 'confidence': 0.8804364}
# {'frame': 2136, 'left': 1178, 'top': 103, 'width': 51, 'height': 58, 'confidence': 0.8642258}
# {'frame': 2136, 'left': 563, 'top': 92, 'width': 98, 'height': 72, 'confidence': 0.8563664}
# {'frame': 2136, 'left': 442, 'top': 134, 'width': 31, 'height': 39, 'confidence': 0.79314}
# {'frame': 2136, 'left': 1003, 'top': 97, 'width': 33, 'height': 46, 'confidence': 0.7507282}
# {'frame': 2137, 'left': 1294, 'top': 365, 'width': 227, 'height': 171, 'confidence': 0.99511284}
# {'frame': 2137, 'left': 919, 'top': 125, 'width': 102, 'height': 84, 'confidence': 0.95013857}
# {'frame': 2137, 'left': 1178, 'top': 104, 'width': 52, 'height': 57, 'confidence': 0.9168605}
# {'frame': 2137, 'left': 914, 'top': 85, 'width': 107, 'height': 52, 'confidence': 0.89366555}
# {'frame': 2137, 'left': 560, 'top': 86, 'width': 101, 'height': 78, 'confidence': 0.8277333}
# {'frame': 2137, 'left': 1002, 'top': 98, 'width': 36, 'height': 47, 'confidence': 0.7859236}
# {'frame': 2138, 'left': 1294, 'top': 364, 'width': 228, 'height': 172, 'confidence': 0.99540776}
# {'frame': 2138, 'left': 1178, 'top': 104, 'width': 51, 'height': 56, 'confidence': 0.90805876}
# {'frame': 2138, 'left': 559, 'top': 85, 'width': 102, 'height': 79, 'confidence': 0.7973738}
# {'frame': 2138, 'left': 442, 'top': 135, 'width': 31, 'height': 37, 'confidence': 0.71486545}
# {'frame': 2139, 'left': 1294, 'top': 365, 'width': 228, 'height': 171, 'confidence': 0.99503267}
# {'frame': 2139, 'left': 1178, 'top': 104, 'width': 51, 'height': 57, 'confidence': 0.9162156}
# {'frame': 2139, 'left': 560, 'top': 88, 'width': 101, 'height': 75, 'confidence': 0.82033354}
# {'frame': 2139, 'left': 915, 'top': 85, 'width': 106, 'height': 119, 'confidence': 0.7809781}
# {'frame': 2139, 'left': 442, 'top': 135, 'width': 31, 'height': 37, 'confidence': 0.7369863}
# {'frame': 2139, 'left': 542, 'top': 116, 'width': 29, 'height': 43, 'confidence': 0.72534615}
# {'frame': 2140, 'left': 1295, 'top': 363, 'width': 227, 'height': 172, 'confidence': 0.9927979}
# {'frame': 2140, 'left': 917, 'top': 98, 'width': 101, 'height': 104, 'confidence': 0.95395976}
# {'frame': 2140, 'left': 1177, 'top': 104, 'width': 52, 'height': 55, 'confidence': 0.93401396}
# {'frame': 2140, 'left': 559, 'top': 89, 'width': 105, 'height': 75, 'confidence': 0.82351345}
# {'frame': 2140, 'left': 929, 'top': 81, 'width': 89, 'height': 56, 'confidence': 0.785528}
# {'frame': 2140, 'left': 875, 'top': 90, 'width': 64, 'height': 49, 'confidence': 0.7406444}
# {'frame': 2140, 'left': 542, 'top': 117, 'width': 29, 'height': 42, 'confidence': 0.73520803}
# {'frame': 2140, 'left': 442, 'top': 135, 'width': 31, 'height': 37, 'confidence': 0.71190315}
# {'frame': 2141, 'left': 1288, 'top': 359, 'width': 234, 'height': 178, 'confidence': 0.99331397}
# {'frame': 2141, 'left': 1177, 'top': 104, 'width': 52, 'height': 55, 'confidence': 0.9293487}
# {'frame': 2141, 'left': 562, 'top': 89, 'width': 100, 'height': 75, 'confidence': 0.8685183}
# {'frame': 2141, 'left': 920, 'top': 84, 'width': 97, 'height': 78, 'confidence': 0.8219636}
# {'frame': 2141, 'left': 542, 'top': 117, 'width': 29, 'height': 42, 'confidence': 0.74590534}

# %%
import pickle
with open("detections.pkl", 'wb') as f:
    pickle.dump(detections, f)
    f.close()
